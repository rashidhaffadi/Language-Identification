# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import six
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from tqdm.notebook import tqdm
from sklearn.ensemble import RandomForestClassifier
from text import create_dataframe, trn_tst, create_split_dataframe
from linear_model import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-abcb0c05d5e0> in <module>
#       6 from sklearn.ensemble import RandomForestClassifier
#       7 from text import create_dataframe, trn_tst, create_split_dataframe
# ----> 8 from linear_model import *
#
# ModuleNotFoundError: No module named 'linear_model'

# %%
def test_model(m, test_params):
    """
    m: one of ["lg", "svm", "rf", "nb"]
    """
    max_words, p, max_lenght = 25000, 0.75, 25
    # create dataframe for train and test
    data = create_dataframe(labels, max_words=max_words)
    trn_df, tst_df = trn_tst(data, p)
    tst_df = create_split_dataframe(tst_df, max_lenght)    
    x_trn, y_trn = trn_df['text'], trn_df['label']
    x_tst, y_tst = tst_df['text'], tst_df['label']
    scores = main(test_params, x_trn, x_tst, y_trn, y_tst, m=m)
#     plt.style.use("ggplot")
#     scores.mean().plot(figsize=(10, 10), kind='bar')
    print("means are {}".format(scores.mean()))
    return scores

def test_data(m, max_data=[]):

    p, max_lenght, test_params = 0.6, 10, {"char":[(1, 1), (1, 2)]}
    # create dataframe for train and test
    scores = []
    names = []
    for max_words in tqdm(max_data):
        data = create_dataframe(labels, max_words=max_words)
        trn_df, tst_df = trn_tst(data, p)
        tst_df = create_split_dataframe(tst_df, max_lenght)    
        x_trn, y_trn = trn_df['text'], trn_df['label']
        x_tst, y_tst = tst_df['text'], tst_df['label']
        tmp = main(test_params, x_trn, x_tst, y_trn, y_tst, m=m).mean()
        names += list(map(lambda r: r+"_"+str(max_words), list(tmp.index)))
        scores += tmp.tolist()
#     plt.style.use("ggplot")
#     scores.mean().plot(figsize=(10, 10), kind='bar')
#     print("means are {}".format(scores.mean()))
    return pd.DataFrame({"model":names, 'score':scores})

def test_sentence_lenghts(m, max_lenghts=[]):
    max_words, p, test_params = 20000, 0.75, {"char":[(1, 4)]}
    # create dataframe for train and test
    scores = []
    names = []
    data = create_dataframe(labels, max_words=max_words)
    trn_df, tst_df0 = trn_tst(data, p)
    x_trn, y_trn = trn_df['text'], trn_df['label']
    for max_lenght in tqdm(max_lenghts):
        tst_df = create_split_dataframe(tst_df0, max_lenght)    
        x_tst, y_tst = tst_df['text'], tst_df['label']
        tmp = main(test_params, x_trn, x_tst, y_trn, y_tst, m=m).mean()
        names += list(map(lambda r: r+"_"+str(max_lenght), list(tmp.index)))
        scores += tmp.tolist()
#     plt.style.use("ggplot")
#     scores.mean().plot(figsize=(10, 10), kind='bar')
#     print("means are {}".format(scores.mean()))
    return pd.DataFrame({"model":names, 'score':scores})

def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')

    mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)

    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in  six.iteritems(mpl_table._cells):
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax

# %% [markdown]
# # Test Logistic Regression

# %%
m, test_params = "lrg", {"char":[(1, 5)]}# (1, 1), (1, 2), (1, 3), (1, 4), (1, 5)
scores = test_model(m, test_params)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 71.96it/s]
# means are accuracy-score_5_char    0.770141
# f1-score_5_char          0.790685
# dtype: float64

# %%
scores
# Out:
#      languages  accuracy-score_1_char  f1-score_1_char  accuracy-score_2_char  \
# 0    Bulgarian                0.66518         0.882834               0.781445
# 1        Czech                0.66518         0.687616               0.781445
# 2       Danish                0.66518         0.745512               0.781445
# 3       German                0.66518         0.599444               0.781445
# 4        Greek                0.66518         0.913919               0.781445
# 5      English                0.66518         0.534712               0.781445
# 6      Spanish                0.66518         0.427921               0.781445
# 7     Estonian                0.66518         0.642317               0.781445
# 8      Finnish                0.66518         0.641457               0.781445
# 9       French                0.66518         0.587601               0.781445
# 10   Hungarian                0.66518         0.861723               0.781445
# 11     Italian                0.66518         0.430233               0.781445
# 12  Lithuanian                0.66518         0.609059               0.781445
# 13     Latvian                0.66518         0.804746               0.781445
# 14       Dutch                0.66518         0.545455               0.781445
# 15      Polish                0.66518         0.880423               0.781445
# 16  Portuguese                0.66518         0.652308               0.781445
# 17    Romanian                0.66518         0.588131               0.781445
# 18      Slovak                0.66518         0.326400               0.781445
# 19   Slovenian                0.66518         0.617354               0.781445
# 20     Swedish                0.66518         0.690382               0.781445
#
#     f1-score_2_char  accuracy-score_3_char  f1-score_3_char  \
# 0          0.751347                0.80107         0.636660
# 1          0.747535                0.80107         0.772112
# 2          0.820675                0.80107         0.861376
# 3          0.728027                0.80107         0.789426
# 4          0.833751                0.80107         0.756061
# 5          0.817625                0.80107         0.868639
# 6          0.681638                0.80107         0.744304
# 7          0.807273                0.80107         0.840580
# 8          0.746341                0.80107         0.791519
# 9          0.806005                0.80107         0.843429
# 10         0.911392                0.80107         0.919740
# 11         0.738386                0.80107         0.810939
# 12         0.742574                0.80107         0.780229
# 13         0.875138                0.80107         0.881166
# 14         0.743889                0.80107         0.817891
# 15         0.927039                0.80107         0.917853
# 16         0.777551                0.80107         0.822034
# 17         0.746327                0.80107         0.784758
# 18         0.568421                0.80107         0.637681
# 19         0.814446                0.80107         0.833539
# 20         0.798489                0.80107         0.824121
#
#     accuracy-score_4_char  f1-score_4_char
# 0                0.794231         0.548623
# 1                0.794231         0.760776
# 2                0.794231         0.876068
# 3                0.794231         0.819484
# 4                0.794231         0.697902
# 5                0.794231         0.871311
# 6                0.794231         0.772671
# 7                0.794231         0.844282
# 8                0.794231         0.819277
# 9                0.794231         0.851598
# 10               0.794231         0.911929
# 11               0.794231         0.842975
# 12               0.794231         0.795158
# 13               0.794231         0.876147
# 14               0.794231         0.837158
# 15               0.794231         0.909497
# 16               0.794231         0.813187
# 17               0.794231         0.800857
# 18               0.794231         0.640351
# 19               0.794231         0.829814
# 20               0.794231         0.829146

# %%
scores.to_pickle("./models/scores_lrg.pkl")

# %%
m, max_lenghts = "lrg", [3, 5, 7, 11, 17, 19, 21, 27]

scores = test_sentence_lenghts(m, max_lenghts)

scores.to_pickle("./models/lrg_sentence_lenghts.pkl")

scores = scores.set_index("model")

rows = list(map(lambda r:True if "f1" in r.split("-") else False, scores.index))

scores = scores.loc[rows]

plt.style.use("ggplot")
# plt.figure(figsize=(15, 15))
# idxs = [i for i in range(len(scores)) if i%2 != 0]
x = scores_f.loc[:, 'model']
x = list(map(lambda r: r.split('_')[-1], x))
# x = [x[i] for i in range(len(scores)) if i%2 != 0]
y = scores_f.loc[:, 'score']
# y = [y[i] for i in range(len(scores)) if i%2 != 0]

plt.plot(x, y, "ro--")
plt.xlabel("Max Sentence Lenght")
plt.ylabel("F1 Score")
plt.savefig("./models/lrg_sentence_lenghts.png")
plt.show()
# plt.close()
# scores.plot(x="model", y="score", )
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 29.37it/s]
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
scores
# Out:
#                  model     score
# 0    f1-score_3_char_3  0.481666
# 1    f1-score_4_char_3  0.492417
# 2    f1-score_3_char_5  0.583430
# 3    f1-score_4_char_5  0.597277
# 4    f1-score_3_char_7  0.653156
# 5    f1-score_4_char_7  0.667193
# 6   f1-score_3_char_11  0.740901
# 7   f1-score_4_char_11  0.753042
# 8   f1-score_3_char_17  0.815599
# 9   f1-score_4_char_17  0.825686
# 10  f1-score_3_char_19  0.830778
# 11  f1-score_4_char_19  0.839709

# %%
# m, max_words, p = "lg", 50000, 0.6
# # create dataframe for train and test
# data = create_dataframe(labels, max_words=max_words)
# trn_df, tst_df = trn_tst(data, p)
# x_trn, y_trn = trn_df['text'], trn_df['label']

# x_tst, y_tst = tst_df['text'], tst_df['label']
# scores = main(test_params, x_trn, x_tst, y_trn, y_tst, m=m)
# Out:
# training model (Logistic Regression) with ngram_range=(1, 1), and analyser_type=char.
# training model (Logistic Regression) with ngram_range=(1, 2), and analyser_type=char.

# %%
scores = pd.read_pickle("./models/scores_lrg.pkl")
scores.mean().to_csv("./models/lrg_means.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
means = pd.read_csv("./models/lrg_means.csv")

means.plot(x="n-gram", y=["f1_score", "accuracy"], kind="bar")
plt.savefig("./models/lrg_ngram_range.png")

# %%
means = means.set_index('n-gram')
means = means.reset_index()

# %%
render_mpl_table(means.round(2), header_columns=0, col_width=2.0)
plt.savefig("./models/lrg_ngram_range_table.png")

# %%
info = pd.read_csv('europarl_info.csv')
render_mpl_table(info, header_columns=0, col_width=2.0)
plt.savefig("./models/dataset_info.png")

# %% [markdown]
# # Test NBaiyes

# %%
m, test_params = "nb", {"char":[(1, 1), (1, 2), (1, 3), (1, 4)]}# (1, 5)
scores = test_model(m, test_params)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 67.29it/s]
# means are accuracy-score_5_char    0.880059
# f1-score_5_char          0.878186
# dtype: float64

# %%
scores.to_pickle("./models/scores_nb.pkl")

# %%
scores = pd.read_pickle("./models/scores_nb.pkl")

# %%
scores.mean().to_csv("./models/nb_means.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
means = pd.read_csv("./models/nb_means.csv")

means.plot(x="n-gram", y=["f1_score", "accuracy"], kind="bar")
plt.savefig("./models/nb_ngram_range.png")

# %%
m, max_lenghts = "nb", [3, 5, 7, 11, 17, 19, 21, 27]

scores = test_sentence_lenghts(m, max_lenghts)

scores.to_pickle("./models/nb_sentence_lenghts.pkl")

plt.style.use("ggplot")
# plt.figure(figsize=(15, 15))
# idxs = [i for i in range(len(scores)) if i%2 != 0]
x = scores.loc[:, 'model']
x = list(map(lambda r: r.split('_')[-1], x))
# x = [x[i] for i in range(len(scores)) if i%2 != 0]
y = scores.loc[:, 'score']
# y = [y[i] for i in range(len(scores)) if i%2 != 0]

plt.plot(x, y, "ro--")
plt.xlabel("Max Sentence Lenght")
plt.ylabel("F1 Score")
plt.savefig("./models/nb_sentence_lenghts.png")
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 76.15it/s]
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
means = pd.read_csv("./models/nb_means.csv")
means = means.set_index("n-gram")
means = means.reset_index()
render_mpl_table(means.round(2), header_columns=0, col_width=2.0)
plt.savefig("./models/nb_ngram_range_table.png")

# %% [markdown]
# # Test SVM

# %%
m, test_params = "svm", {"char":[(1, 5)]}# (1, 1), (1, 2), (1, 3), (1, 4)
scores = test_model(m, test_params)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 70.96it/s]
# means are accuracy-score_5_char    0.871948
# f1-score_5_char          0.869930
# dtype: float64

# %%
scores.to_pickle("./models/scores_svm.pkl")

# %%
scores = pd.read_pickle("./models/scores_svm.pkl")

scores.mean().to_csv("./models/svm_means.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.style.use('ggplot')
means = pd.read_csv("./models/nb_means.csv")

means.plot(x="n-gram", y=["f1_score", "accuracy"], kind="bar")
plt.savefig("./models/svm_ngram_range.png")

# %%
m, max_lenghts = "svm", [3, 5, 7, 11, 17, 19, 21, 27]

scores = test_sentence_lenghts(m, max_lenghts)

scores.to_pickle("./models/svm_sentence_lenghts.pkl")

plt.style.use("ggplot")
# plt.figure(figsize=(15, 15))
# idxs = [i for i in range(len(scores)) if i%2 != 0]
x = scores.loc[:, 'model']
x = list(map(lambda r: r.split('_')[-1], x))
# x = [x[i] for i in range(len(scores)) if i%2 != 0]
y = scores.loc[:, 'score']
# y = [y[i] for i in range(len(scores)) if i%2 != 0]

plt.plot(x, y, "ro--")
plt.xlabel("Max Sentence Lenght")
plt.ylabel("F1 Score")
plt.savefig("./models/svm_sentence_lenghts.png")
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 66.92it/s]
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
means = pd.read_csv("./models/svm_means.csv")
means = means.set_index("n-gram")
means = means.reset_index()
render_mpl_table(means.round(2), header_columns=0, col_width=2.0)
plt.savefig("./models/svm_ngram_range_table.png")

# %% [markdown]
# # Test Random Forest

# %%
m, test_params = "rf", {"char":[(1, 5)]}# (1, 1), (1, 2), (1, 3), (1, 4)
scores = test_model(m, test_params)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 70.11it/s]
# means are accuracy-score_5_char    0.047526
# f1-score_5_char          0.004321
# dtype: float64

# %%
scores.to_pickle("./models/scores_rf.pkl")

# %%
scores.mean().to_csv("./models/rf_means.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
plt.style.use('ggplot')
means = pd.read_csv("./models/nb_means.csv")

means.plot(x="n-gram", y=["f1_score", "accuracy"], kind="bar")
plt.savefig("./models/svm_ngram_range.png")

# %%
m, max_lenghts = "svm", [3, 5, 7, 11, 17, 19, 21, 27]

scores = test_sentence_lenghts(m, max_lenghts)

scores.to_pickle("./models/svm_sentence_lenghts.pkl")

plt.style.use("ggplot")
# plt.figure(figsize=(15, 15))
# idxs = [i for i in range(len(scores)) if i%2 != 0]
x = scores.loc[:, 'model']
x = list(map(lambda r: r.split('_')[-1], x))
# x = [x[i] for i in range(len(scores)) if i%2 != 0]
y = scores.loc[:, 'score']
# y = [y[i] for i in range(len(scores)) if i%2 != 0]

plt.plot(x, y, "ro--")
plt.xlabel("Max Sentence Lenght")
plt.ylabel("F1 Score")
plt.savefig("./models/svm_sentence_lenghts.png")
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 66.92it/s]
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
means = pd.read_csv("./models/svm_means.csv")
means = means.set_index("n-gram")
means = means.reset_index()
render_mpl_table(means.round(2), header_columns=0, col_width=2.0)
plt.savefig("./models/svm_ngram_range_table.png")
